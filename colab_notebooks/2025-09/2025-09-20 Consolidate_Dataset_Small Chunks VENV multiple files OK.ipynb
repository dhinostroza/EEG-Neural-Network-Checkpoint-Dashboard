# %%
# !rm -f /content/drive/MyDrive/shhs_consolidated_data/*

# %%
# ==============================================================================
# SCRIPT TO CONSOLIDATE THE DATASET (DEFINITIVE, MEMORY-SAFE)
# This script uses a small chunk size to prevent memory crashes, ensuring a
# stable and resumable pre-processing run.
# Run this script ONCE on a CPU runtime with high RAM.
# ==============================================================================

import os
import sys
from google.colab import auth, drive

# --- 1. SETUP THE COLAB ENVIRONMENT ---
print("--- Step 1: Preparing the main Colab environment ---")
try:
    auth.authenticate_user()
    print("✅ Authentication successful.")
    drive.mount('/content/drive', force_remount=True)
    print("✅ Google Drive mounted successfully.")
except Exception as e:
    sys.exit(f"❌ FATAL ERROR: Could not set up environment. Details: {e}")

# --- 2. CREATE AND PROVISION THE ISOLATED ENVIRONMENT ---
print("\n--- Step 2: Creating and provisioning the isolated consolidation environment ---")
# !pip install --upgrade -q virtualenv
print("  -> `virtualenv` installed.")
# !virtualenv consolidate_env
print("  -> Virtual environment 'consolidate_env' created successfully.")
# !consolidate_env/bin/pip install --upgrade -q pip "pandas==2.2.2" "pyarrow==15.0.2" "fsspec>=2023.6.0" gcsfs google-auth
print("  -> All dependencies installed successfully into 'consolidate_env'.")


# --- 3. CREATE AND RUN THE CONSOLIDATION LOGIC SCRIPT ---
print("\n--- Step 3: Preparing and executing the consolidation logic in the isolated environment ---")

python_script_logic = r'''
import pandas as pd
import numpy as np
import os
import sys
import time
import glob
import subprocess

# --- CONFIGURATION ---
GCS_MANIFEST_PATH = "gs://shhs-sleepedfx-data-bucket/metadata/shhs_dataset_manifest.csv"
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/shhs_consolidated_data/"
PROGRESS_FILE_PATH = os.path.join(DRIVE_OUTPUT_DIR, "_progress.txt")
# --- MODIFICATION: Reduced chunk size to a safe value to prevent memory crashes ---
CHUNK_SIZE = 50

print("\n" + "="*80)
print("--- DATA CONSOLIDATION SCRIPT (RUNNING IN ISOLATED ENV) ---")
print(f"  -> Output Directory: {DRIVE_OUTPUT_DIR}")
print(f"  -> Chunk Size: {CHUNK_SIZE} files per chunk")
print("="*80 + "\n")

# --- Prepare Environment ---
os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

# --- Load Manifest ---
print("--- Step A: Loading manifest... ---")
try:
    manifest_df = pd.read_csv(GCS_MANIFEST_PATH)
    all_file_paths = manifest_df['file_path'].tolist()
    print(f"✅ Manifest loaded. Found {len(all_file_paths)} files to process.")
except Exception as e:
    sys.exit(f"❌ FATAL ERROR: Could not load manifest file from GCS. Details: {e}")

# --- Check for Progress ---
processed_files = set()
if os.path.exists(PROGRESS_FILE_PATH):
    with open(PROGRESS_FILE_PATH, 'r') as f:
        processed_files = set(f.read().splitlines())
    print(f"✅ Found progress file. Resuming. {len(processed_files)} files already processed.")

# --- Process Files in Chunks ---
files_to_process = [fp for fp in all_file_paths if fp not in processed_files]
print(f"\n--- Step B: Consolidating data from {len(files_to_process)} remaining files ---")
print("This is a very long process. Progress will be updated periodically.")
time.sleep(2)

# Determine starting chunk number based on existing files
chunk_num = len(glob.glob(os.path.join(DRIVE_OUTPUT_DIR, "spectrograms_*.npy")))
all_spectrograms = []
all_labels = []

for i, f_path in enumerate(files_to_process):
    try:
        if (i + 1) % 10 == 0 or i == len(files_to_process) - 1 or i == 0:
            print(f"\r  -> Progress: [{i+1}/{len(files_to_process)}] | Overall: [{len(processed_files) + i + 1}/{len(all_file_paths)}] | File: {os.path.basename(f_path)}", end="")

        df = pd.read_parquet(f_path)
        df_filtered = df[df['label'].isin([0, 1, 2, 3, 4])]

        labels = df_filtered['label'].values.astype(np.int64)
        spectrograms_flat = df_filtered.drop('label', axis=1).values.astype(np.float32)

        all_labels.extend(labels.tolist())
        all_spectrograms.extend(spectrograms_flat.tolist())
        processed_files.add(f_path)

        if (i > 0 and (i + 1) % CHUNK_SIZE == 0) or ((i + 1) == len(files_to_process) and len(all_labels) > 0):
            print(f"\n     -> 💾 CHUNK COMPLETE: Saving chunk #{chunk_num} with {len(all_labels)} epochs...")

            chunk_data_path = os.path.join(DRIVE_OUTPUT_DIR, f"spectrograms_{chunk_num}.npy")
            chunk_labels_path = os.path.join(DRIVE_OUTPUT_DIR, f"labels_{chunk_num}.npy")

            np.save(chunk_data_path, np.array(all_spectrograms, dtype=np.float32))
            np.save(chunk_labels_path, np.array(all_labels, dtype=np.int64))

            with open(PROGRESS_FILE_PATH, 'w') as f:
                f.write("\n".join(sorted(list(processed_files))))

            print(f"        ...✅ Chunk #{chunk_num} saved successfully.")

            all_spectrograms.clear()
            all_labels.clear()
            chunk_num += 1

    except Exception as e:
        print(f"\\n     -> ⚠️ WARNING: Could not process {os.path.basename(f_path)}. Skipping. Error: {e}")

print("\n\n--- Step C: Final verification ---")
final_chunks = glob.glob(os.path.join(DRIVE_OUTPUT_DIR, "spectrograms_*.npy"))
print(f"  -> Found {len(final_chunks)} saved data chunks in the output directory.")

print("\\n" + "="*80)
print("🎉 SCRIPT COMPLETE 🎉")
print("Your dataset is now consolidated into manageable chunks in your Google Drive.")
print("You can now use the final, simplified training script on a GPU runtime.")
print("="*80)
'''

# Write the script to a file
with open("run_consolidation.py", "w") as f:
    f.write(python_script_logic)

# Execute the script using the virtual environment's python
# !consolidate_env/bin/python run_consolidation.py

print("\n--- Script execution finished. ---")
# Out:
# --- Step 1: Preparing the main Colab environment ---
# ✅ Authentication successful.
# Mounted at /content/drive
# ✅ Google Drive mounted successfully.
#
# --- Step 2: Creating and provisioning the isolated consolidation environment ---
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 31.5 MB/s eta 0:00:00
#   -> `virtualenv` installed.
# created virtual environment CPython3.12.11.final.0-64 in 303ms
#   creator CPython3Posix(dest=/content/consolidate_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
#   -> Virtual environment 'consolidate_env' created successfully.
#   -> All dependencies installed successfully into 'consolidate_env'.
#
# --- Step 3: Preparing and executing the consolidation logic in the isolated environment ---
#
# ================================================================================
# --- DATA CONSOLIDATION SCRIPT (RUNNING IN ISOLATED ENV) ---
#   -> Output Directory: /content/drive/MyDrive/shhs_consolidated_data/
#   -> Chunk Size: 50 files per chunk
# ================================================================================
#
# --- Step A: Loading manifest... ---
# ✅ Manifest loaded. Found 8431 files to process.
# ✅ Found progress file. Resuming. 1 files already processed.
#
# --- Step B: Consolidating data from 8431 remaining files ---
# This is a very long process. Progress will be updated periodically.
#   -> Progress: [50/8431] | Overall: [100/8431] | File: shhs1-200050.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #0 with 50073 epochs...
#         ...✅ Chunk #0 saved successfully.
#   -> Progress: [100/8431] | Overall: [200/8431] | File: shhs1-200100.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #1 with 48912 epochs...
#         ...✅ Chunk #1 saved successfully.
#   -> Progress: [150/8431] | Overall: [300/8431] | File: shhs1-200152.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #2 with 50083 epochs...
#         ...✅ Chunk #2 saved successfully.
#   -> Progress: [200/8431] | Overall: [400/8431] | File: shhs1-200202.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #3 with 50336 epochs...
#         ...✅ Chunk #3 saved successfully.
#   -> Progress: [250/8431] | Overall: [500/8431] | File: shhs1-200253.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #4 with 49802 epochs...
#         ...✅ Chunk #4 saved successfully.
#   -> Progress: [300/8431] | Overall: [600/8431] | File: shhs1-200304.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #5 with 50768 epochs...
#         ...✅ Chunk #5 saved successfully.
#   -> Progress: [350/8431] | Overall: [700/8431] | File: shhs1-200354.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #6 with 49389 epochs...
#         ...✅ Chunk #6 saved successfully.
#   -> Progress: [400/8431] | Overall: [800/8431] | File: shhs1-200404.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #7 with 49230 epochs...
#         ...✅ Chunk #7 saved successfully.
#   -> Progress: [450/8431] | Overall: [900/8431] | File: shhs1-200454.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #8 with 49850 epochs...
#         ...✅ Chunk #8 saved successfully.
#   -> Progress: [500/8431] | Overall: [1000/8431] | File: shhs1-200504.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #9 with 50393 epochs...
#         ...✅ Chunk #9 saved successfully.
#   -> Progress: [550/8431] | Overall: [1100/8431] | File: shhs1-200554.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #10 with 50821 epochs...
#         ...✅ Chunk #10 saved successfully.
#   -> Progress: [600/8431] | Overall: [1200/8431] | File: shhs1-200604.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #11 with 48688 epochs...
#         ...✅ Chunk #11 saved successfully.
#   -> Progress: [650/8431] | Overall: [1300/8431] | File: shhs1-200654.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #12 with 49847 epochs...
#         ...✅ Chunk #12 saved successfully.
#   -> Progress: [700/8431] | Overall: [1400/8431] | File: shhs1-200704.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #13 with 49303 epochs...
#         ...✅ Chunk #13 saved successfully.
#   -> Progress: [750/8431] | Overall: [1500/8431] | File: shhs1-200754.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #14 with 50224 epochs...
#         ...✅ Chunk #14 saved successfully.
#   -> Progress: [800/8431] | Overall: [1600/8431] | File: shhs1-200804.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #15 with 49943 epochs...
#         ...✅ Chunk #15 saved successfully.
#   -> Progress: [850/8431] | Overall: [1700/8431] | File: shhs1-200854.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #16 with 49593 epochs...
#         ...✅ Chunk #16 saved successfully.
#   -> Progress: [900/8431] | Overall: [1800/8431] | File: shhs1-200905.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #17 with 50630 epochs...
#         ...✅ Chunk #17 saved successfully.
#   -> Progress: [950/8431] | Overall: [1900/8431] | File: shhs1-200955.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #18 with 51197 epochs...
#         ...✅ Chunk #18 saved successfully.
#   -> Progress: [1000/8431] | Overall: [2000/8431] | File: shhs1-201005.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #19 with 49905 epochs...
#         ...✅ Chunk #19 saved successfully.
#   -> Progress: [1050/8431] | Overall: [2100/8431] | File: shhs1-201055.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #20 with 50534 epochs...
#         ...✅ Chunk #20 saved successfully.
#   -> Progress: [1100/8431] | Overall: [2200/8431] | File: shhs1-201105.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #21 with 49904 epochs...
#         ...✅ Chunk #21 saved successfully.
#   -> Progress: [1150/8431] | Overall: [2300/8431] | File: shhs1-201156.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #22 with 50393 epochs...
#         ...✅ Chunk #22 saved successfully.
#   -> Progress: [1200/8431] | Overall: [2400/8431] | File: shhs1-201206.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #23 with 50600 epochs...
#         ...✅ Chunk #23 saved successfully.
#   -> Progress: [1250/8431] | Overall: [2500/8431] | File: shhs1-201256.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #24 with 50355 epochs...
#         ...✅ Chunk #24 saved successfully.
#   -> Progress: [1300/8431] | Overall: [2600/8431] | File: shhs1-201306.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #25 with 50980 epochs...
#         ...✅ Chunk #25 saved successfully.
#   -> Progress: [1350/8431] | Overall: [2700/8431] | File: shhs1-201356.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #26 with 49894 epochs...
#         ...✅ Chunk #26 saved successfully.
#   -> Progress: [1400/8431] | Overall: [2800/8431] | File: shhs1-201406.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #27 with 50536 epochs...
#         ...✅ Chunk #27 saved successfully.
#   -> Progress: [1450/8431] | Overall: [2900/8431] | File: shhs1-201456.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #28 with 50438 epochs...
#         ...✅ Chunk #28 saved successfully.
#   -> Progress: [1500/8431] | Overall: [3000/8431] | File: shhs1-201506.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #29 with 50970 epochs...
#         ...✅ Chunk #29 saved successfully.
#   -> Progress: [1550/8431] | Overall: [3100/8431] | File: shhs1-201556.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #30 with 50066 epochs...
#         ...✅ Chunk #30 saved successfully.
#   -> Progress: [1600/8431] | Overall: [3200/8431] | File: shhs1-201606.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #31 with 52072 epochs...
#         ...✅ Chunk #31 saved successfully.
#   -> Progress: [1650/8431] | Overall: [3300/8431] | File: shhs1-201656.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #32 with 50823 epochs...
#         ...✅ Chunk #32 saved successfully.
#   -> Progress: [1700/8431] | Overall: [3400/8431] | File: shhs1-201707.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #33 with 50585 epochs...
#         ...✅ Chunk #33 saved successfully.
#   -> Progress: [1750/8431] | Overall: [3500/8431] | File: shhs1-201757.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #34 with 48880 epochs...
#         ...✅ Chunk #34 saved successfully.
#   -> Progress: [1800/8431] | Overall: [3600/8431] | File: shhs1-201807.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #35 with 49242 epochs...
#         ...✅ Chunk #35 saved successfully.
#   -> Progress: [1850/8431] | Overall: [3700/8431] | File: shhs1-201858.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #36 with 50054 epochs...
#         ...✅ Chunk #36 saved successfully.
#   -> Progress: [1900/8431] | Overall: [3800/8431] | File: shhs1-201908.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #37 with 49027 epochs...
#         ...✅ Chunk #37 saved successfully.
#   -> Progress: [1950/8431] | Overall: [3900/8431] | File: shhs1-201958.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #38 with 49281 epochs...
#         ...✅ Chunk #38 saved successfully.
#   -> Progress: [2000/8431] | Overall: [4000/8431] | File: shhs1-202008.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #39 with 49392 epochs...
#         ...✅ Chunk #39 saved successfully.
#   -> Progress: [2050/8431] | Overall: [4100/8431] | File: shhs1-202058.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #40 with 49428 epochs...
#         ...✅ Chunk #40 saved successfully.
#   -> Progress: [2100/8431] | Overall: [4200/8431] | File: shhs1-202108.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #41 with 50439 epochs...
#         ...✅ Chunk #41 saved successfully.
#   -> Progress: [2150/8431] | Overall: [4300/8431] | File: shhs1-202158.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #42 with 50399 epochs...
#         ...✅ Chunk #42 saved successfully.
#   -> Progress: [2200/8431] | Overall: [4400/8431] | File: shhs1-202208.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #43 with 48960 epochs...
#         ...✅ Chunk #43 saved successfully.
#   -> Progress: [2250/8431] | Overall: [4500/8431] | File: shhs1-202259.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #44 with 49166 epochs...
#         ...✅ Chunk #44 saved successfully.
#   -> Progress: [2300/8431] | Overall: [4600/8431] | File: shhs1-202310.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #45 with 49961 epochs...
#         ...✅ Chunk #45 saved successfully.
#   -> Progress: [2350/8431] | Overall: [4700/8431] | File: shhs1-202362.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #46 with 49746 epochs...
#         ...✅ Chunk #46 saved successfully.
#   -> Progress: [2400/8431] | Overall: [4800/8431] | File: shhs1-202412.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #47 with 50320 epochs...
#         ...✅ Chunk #47 saved successfully.
#   -> Progress: [2450/8431] | Overall: [4900/8431] | File: shhs1-202462.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #48 with 49857 epochs...
#         ...✅ Chunk #48 saved successfully.
#   -> Progress: [2500/8431] | Overall: [5000/8431] | File: shhs1-202512.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #49 with 50312 epochs...
#         ...✅ Chunk #49 saved successfully.
#   -> Progress: [2550/8431] | Overall: [5100/8431] | File: shhs1-202562.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #50 with 50848 epochs...
#         ...✅ Chunk #50 saved successfully.
#   -> Progress: [2600/8431] | Overall: [5200/8431] | File: shhs1-202612.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #51 with 50237 epochs...
#         ...✅ Chunk #51 saved successfully.
#   -> Progress: [2650/8431] | Overall: [5300/8431] | File: shhs1-202662.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #52 with 50125 epochs...
#         ...✅ Chunk #52 saved successfully.
#   -> Progress: [2700/8431] | Overall: [5400/8431] | File: shhs1-202712.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #53 with 47897 epochs...
#         ...✅ Chunk #53 saved successfully.
#   -> Progress: [2750/8431] | Overall: [5500/8431] | File: shhs1-202762.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #54 with 48219 epochs...
#         ...✅ Chunk #54 saved successfully.
#   -> Progress: [2800/8431] | Overall: [5600/8431] | File: shhs1-202812.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #55 with 49798 epochs...
#         ...✅ Chunk #55 saved successfully.
#   -> Progress: [2850/8431] | Overall: [5700/8431] | File: shhs1-202862.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #56 with 50792 epochs...
#         ...✅ Chunk #56 saved successfully.
#   -> Progress: [2900/8431] | Overall: [5800/8431] | File: shhs1-202912.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #57 with 48929 epochs...
#         ...✅ Chunk #57 saved successfully.
#   -> Progress: [2950/8431] | Overall: [5900/8431] | File: shhs1-202962.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #58 with 51899 epochs...
#         ...✅ Chunk #58 saved successfully.
#   -> Progress: [3000/8431] | Overall: [6000/8431] | File: shhs1-203012.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #59 with 51771 epochs...
#         ...✅ Chunk #59 saved successfully.
#   -> Progress: [3050/8431] | Overall: [6100/8431] | File: shhs1-203062.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #60 with 51582 epochs...
#         ...✅ Chunk #60 saved successfully.
#   -> Progress: [3100/8431] | Overall: [6200/8431] | File: shhs1-203112.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #61 with 52093 epochs...
#         ...✅ Chunk #61 saved successfully.
#   -> Progress: [3150/8431] | Overall: [6300/8431] | File: shhs1-203162.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #62 with 50135 epochs...
#         ...✅ Chunk #62 saved successfully.
#   -> Progress: [3200/8431] | Overall: [6400/8431] | File: shhs1-203213.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #63 with 50975 epochs...
#         ...✅ Chunk #63 saved successfully.
#   -> Progress: [3250/8431] | Overall: [6500/8431] | File: shhs1-203263.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #64 with 50168 epochs...
#         ...✅ Chunk #64 saved successfully.
#   -> Progress: [3300/8431] | Overall: [6600/8431] | File: shhs1-203313.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #65 with 50751 epochs...
#         ...✅ Chunk #65 saved successfully.
#   -> Progress: [3350/8431] | Overall: [6700/8431] | File: shhs1-203363.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #66 with 51518 epochs...
#         ...✅ Chunk #66 saved successfully.
#   -> Progress: [3400/8431] | Overall: [6800/8431] | File: shhs1-203413.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #67 with 51185 epochs...
#         ...✅ Chunk #67 saved successfully.
#   -> Progress: [3450/8431] | Overall: [6900/8431] | File: shhs1-203463.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #68 with 51576 epochs...
#         ...✅ Chunk #68 saved successfully.
#   -> Progress: [3500/8431] | Overall: [7000/8431] | File: shhs1-203513.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #69 with 51024 epochs...
#         ...✅ Chunk #69 saved successfully.
#   -> Progress: [3550/8431] | Overall: [7100/8431] | File: shhs1-203563.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #70 with 50639 epochs...
#         ...✅ Chunk #70 saved successfully.
#   -> Progress: [3600/8431] | Overall: [7200/8431] | File: shhs1-203613.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #71 with 51326 epochs...
#         ...✅ Chunk #71 saved successfully.
#   -> Progress: [3650/8431] | Overall: [7300/8431] | File: shhs1-203663.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #72 with 50582 epochs...
#         ...✅ Chunk #72 saved successfully.
#   -> Progress: [3700/8431] | Overall: [7400/8431] | File: shhs1-203713.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #73 with 51917 epochs...
#         ...✅ Chunk #73 saved successfully.
#   -> Progress: [3750/8431] | Overall: [7500/8431] | File: shhs1-203763.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #74 with 51730 epochs...
#         ...✅ Chunk #74 saved successfully.
#   -> Progress: [3800/8431] | Overall: [7600/8431] | File: shhs1-203813.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #75 with 50695 epochs...
#         ...✅ Chunk #75 saved successfully.
#   -> Progress: [3850/8431] | Overall: [7700/8431] | File: shhs1-203863.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #76 with 51930 epochs...
#         ...✅ Chunk #76 saved successfully.
#   -> Progress: [3900/8431] | Overall: [7800/8431] | File: shhs1-203913.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #77 with 50928 epochs...
#         ...✅ Chunk #77 saved successfully.
#   -> Progress: [3950/8431] | Overall: [7900/8431] | File: shhs1-203963.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #78 with 51955 epochs...
#         ...✅ Chunk #78 saved successfully.
#   -> Progress: [4000/8431] | Overall: [8000/8431] | File: shhs1-204013.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #79 with 51617 epochs...
#         ...✅ Chunk #79 saved successfully.
#   -> Progress: [4050/8431] | Overall: [8100/8431] | File: shhs1-204063.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #80 with 51587 epochs...
#         ...✅ Chunk #80 saved successfully.
#   -> Progress: [4100/8431] | Overall: [8200/8431] | File: shhs1-204113.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #81 with 52049 epochs...
#         ...✅ Chunk #81 saved successfully.
#   -> Progress: [4150/8431] | Overall: [8300/8431] | File: shhs1-204163.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #82 with 51784 epochs...
#         ...✅ Chunk #82 saved successfully.
#   -> Progress: [4200/8431] | Overall: [8400/8431] | File: shhs1-204213.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #83 with 52361 epochs...
#         ...✅ Chunk #83 saved successfully.
#   -> Progress: [4250/8431] | Overall: [8500/8431] | File: shhs1-204264.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #84 with 51984 epochs...
#         ...✅ Chunk #84 saved successfully.
#   -> Progress: [4300/8431] | Overall: [8600/8431] | File: shhs1-204314.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #85 with 52155 epochs...
#         ...✅ Chunk #85 saved successfully.
#   -> Progress: [4350/8431] | Overall: [8700/8431] | File: shhs1-204364.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #86 with 52213 epochs...
#         ...✅ Chunk #86 saved successfully.
#   -> Progress: [4400/8431] | Overall: [8800/8431] | File: shhs1-204414.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #87 with 51711 epochs...
#         ...✅ Chunk #87 saved successfully.
#   -> Progress: [4450/8431] | Overall: [8900/8431] | File: shhs1-204464.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #88 with 52292 epochs...
#         ...✅ Chunk #88 saved successfully.
#   -> Progress: [4500/8431] | Overall: [9000/8431] | File: shhs1-204514.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #89 with 52243 epochs...
#         ...✅ Chunk #89 saved successfully.
#   -> Progress: [4550/8431] | Overall: [9100/8431] | File: shhs1-204564.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #90 with 52093 epochs...
#         ...✅ Chunk #90 saved successfully.
#   -> Progress: [4600/8431] | Overall: [9200/8431] | File: shhs1-204614.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #91 with 51320 epochs...
#         ...✅ Chunk #91 saved successfully.
#   -> Progress: [4650/8431] | Overall: [9300/8431] | File: shhs1-204664.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #92 with 50534 epochs...
#         ...✅ Chunk #92 saved successfully.
#   -> Progress: [4700/8431] | Overall: [9400/8431] | File: shhs1-204714.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #93 with 51219 epochs...
#         ...✅ Chunk #93 saved successfully.
#   -> Progress: [4750/8431] | Overall: [9500/8431] | File: shhs1-204764.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #94 with 51930 epochs...
#         ...✅ Chunk #94 saved successfully.
#   -> Progress: [4800/8431] | Overall: [9600/8431] | File: shhs1-204814.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #95 with 52209 epochs...
#         ...✅ Chunk #95 saved successfully.
#   -> Progress: [4850/8431] | Overall: [9700/8431] | File: shhs1-204864.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #96 with 51879 epochs...
#         ...✅ Chunk #96 saved successfully.
#   -> Progress: [4900/8431] | Overall: [9800/8431] | File: shhs1-204915.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #97 with 52334 epochs...
#         ...✅ Chunk #97 saved successfully.
#   -> Progress: [4950/8431] | Overall: [9900/8431] | File: shhs1-204965.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #98 with 51720 epochs...
#         ...✅ Chunk #98 saved successfully.
#   -> Progress: [5000/8431] | Overall: [10000/8431] | File: shhs1-205015.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #99 with 49216 epochs...
#         ...✅ Chunk #99 saved successfully.
#   -> Progress: [5050/8431] | Overall: [10100/8431] | File: shhs1-205065.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #100 with 48576 epochs...
#         ...✅ Chunk #100 saved successfully.
#   -> Progress: [5100/8431] | Overall: [10200/8431] | File: shhs1-205115.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #101 with 48296 epochs...
#         ...✅ Chunk #101 saved successfully.
#   -> Progress: [5150/8431] | Overall: [10300/8431] | File: shhs1-205165.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #102 with 48594 epochs...
#         ...✅ Chunk #102 saved successfully.
#   -> Progress: [5200/8431] | Overall: [10400/8431] | File: shhs1-205215.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #103 with 49577 epochs...
#         ...✅ Chunk #103 saved successfully.
#   -> Progress: [5250/8431] | Overall: [10500/8431] | File: shhs1-205270.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #104 with 48994 epochs...
#         ...✅ Chunk #104 saved successfully.
#   -> Progress: [5300/8431] | Overall: [10600/8431] | File: shhs1-205320.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #105 with 48883 epochs...
#         ...✅ Chunk #105 saved successfully.
#   -> Progress: [5350/8431] | Overall: [10700/8431] | File: shhs1-205370.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #106 with 50531 epochs...
#         ...✅ Chunk #106 saved successfully.
#   -> Progress: [5400/8431] | Overall: [10800/8431] | File: shhs1-205420.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #107 with 51190 epochs...
#         ...✅ Chunk #107 saved successfully.
#   -> Progress: [5450/8431] | Overall: [10900/8431] | File: shhs1-205470.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #108 with 52125 epochs...
#         ...✅ Chunk #108 saved successfully.
#   -> Progress: [5500/8431] | Overall: [11000/8431] | File: shhs1-205520.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #109 with 51907 epochs...
#         ...✅ Chunk #109 saved successfully.
#   -> Progress: [5550/8431] | Overall: [11100/8431] | File: shhs1-205570.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #110 with 51530 epochs...
#         ...✅ Chunk #110 saved successfully.
#   -> Progress: [5600/8431] | Overall: [11200/8431] | File: shhs1-205620.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #111 with 52256 epochs...
#         ...✅ Chunk #111 saved successfully.
#   -> Progress: [5650/8431] | Overall: [11300/8431] | File: shhs1-205671.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #112 with 50950 epochs...
#         ...✅ Chunk #112 saved successfully.
#   -> Progress: [5700/8431] | Overall: [11400/8431] | File: shhs1-205721.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #113 with 52322 epochs...
#         ...✅ Chunk #113 saved successfully.
#   -> Progress: [5750/8431] | Overall: [11500/8431] | File: shhs1-205771.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #114 with 51865 epochs...
#         ...✅ Chunk #114 saved successfully.
#   -> Progress: [5800/8431] | Overall: [11600/8431] | File: shhs2-200108.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #115 with 55786 epochs...
#         ...✅ Chunk #115 saved successfully.
#   -> Progress: [5850/8431] | Overall: [11700/8431] | File: shhs2-200218.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #116 with 65748 epochs...
#         ...✅ Chunk #116 saved successfully.
#   -> Progress: [5900/8431] | Overall: [11800/8431] | File: shhs2-200395.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #117 with 62187 epochs...
#         ...✅ Chunk #117 saved successfully.
#   -> Progress: [5950/8431] | Overall: [11900/8431] | File: shhs2-200563.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #118 with 63059 epochs...
#         ...✅ Chunk #118 saved successfully.
#   -> Progress: [6000/8431] | Overall: [12000/8431] | File: shhs2-200667.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #119 with 64227 epochs...
#         ...✅ Chunk #119 saved successfully.
#   -> Progress: [6050/8431] | Overall: [12100/8431] | File: shhs2-200763.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #120 with 63734 epochs...
#         ...✅ Chunk #120 saved successfully.
#   -> Progress: [6100/8431] | Overall: [12200/8431] | File: shhs2-200852.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #121 with 65755 epochs...
#         ...✅ Chunk #121 saved successfully.
#   -> Progress: [6150/8431] | Overall: [12300/8431] | File: shhs2-200935.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #122 with 65802 epochs...
#         ...✅ Chunk #122 saved successfully.
#   -> Progress: [6200/8431] | Overall: [12400/8431] | File: shhs2-201030.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #123 with 64238 epochs...
#         ...✅ Chunk #123 saved successfully.
#   -> Progress: [6250/8431] | Overall: [12500/8431] | File: shhs2-201194.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #124 with 64649 epochs...
#         ...✅ Chunk #124 saved successfully.
#   -> Progress: [6300/8431] | Overall: [12600/8431] | File: shhs2-201288.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #125 with 59275 epochs...
#         ...✅ Chunk #125 saved successfully.
#   -> Progress: [6350/8431] | Overall: [12700/8431] | File: shhs2-201384.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #126 with 59892 epochs...
#         ...✅ Chunk #126 saved successfully.
#   -> Progress: [6400/8431] | Overall: [12800/8431] | File: shhs2-201481.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #127 with 59412 epochs...
#         ...✅ Chunk #127 saved successfully.
#   -> Progress: [6450/8431] | Overall: [12900/8431] | File: shhs2-201617.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #128 with 61753 epochs...
#         ...✅ Chunk #128 saved successfully.
#   -> Progress: [6500/8431] | Overall: [13000/8431] | File: shhs2-201789.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #129 with 59582 epochs...
#         ...✅ Chunk #129 saved successfully.
#   -> Progress: [6550/8431] | Overall: [13100/8431] | File: shhs2-201988.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #130 with 57886 epochs...
#         ...✅ Chunk #130 saved successfully.
#   -> Progress: [6600/8431] | Overall: [13200/8431] | File: shhs2-202217.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #131 with 56382 epochs...
#         ...✅ Chunk #131 saved successfully.
#   -> Progress: [6650/8431] | Overall: [13300/8431] | File: shhs2-202465.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #132 with 56218 epochs...
#         ...✅ Chunk #132 saved successfully.
#   -> Progress: [6700/8431] | Overall: [13400/8431] | File: shhs2-202591.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #133 with 54898 epochs...
#         ...✅ Chunk #133 saved successfully.
#   -> Progress: [6750/8431] | Overall: [13500/8431] | File: shhs2-202810.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #134 with 55328 epochs...
#         ...✅ Chunk #134 saved successfully.
#   -> Progress: [6800/8431] | Overall: [13600/8431] | File: shhs2-202968.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #135 with 62099 epochs...
#         ...✅ Chunk #135 saved successfully.
#   -> Progress: [6850/8431] | Overall: [13700/8431] | File: shhs2-203073.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #136 with 63084 epochs...
#         ...✅ Chunk #136 saved successfully.
#   -> Progress: [6900/8431] | Overall: [13800/8431] | File: shhs2-203153.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #137 with 61399 epochs...
#         ...✅ Chunk #137 saved successfully.
#   -> Progress: [6950/8431] | Overall: [13900/8431] | File: shhs2-203238.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #138 with 58924 epochs...
#         ...✅ Chunk #138 saved successfully.
#   -> Progress: [7000/8431] | Overall: [14000/8431] | File: shhs2-203314.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #139 with 58158 epochs...
#         ...✅ Chunk #139 saved successfully.
#   -> Progress: [7050/8431] | Overall: [14100/8431] | File: shhs2-203395.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #140 with 58911 epochs...
#         ...✅ Chunk #140 saved successfully.
#   -> Progress: [7100/8431] | Overall: [14200/8431] | File: shhs2-203478.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #141 with 61505 epochs...
#         ...✅ Chunk #141 saved successfully.
#   -> Progress: [7150/8431] | Overall: [14300/8431] | File: shhs2-203554.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #142 with 59997 epochs...
#         ...✅ Chunk #142 saved successfully.
#   -> Progress: [7200/8431] | Overall: [14400/8431] | File: shhs2-203657.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #143 with 61293 epochs...
#         ...✅ Chunk #143 saved successfully.
#   -> Progress: [7250/8431] | Overall: [14500/8431] | File: shhs2-203742.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #144 with 61082 epochs...
#         ...✅ Chunk #144 saved successfully.
#   -> Progress: [7300/8431] | Overall: [14600/8431] | File: shhs2-203842.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #145 with 64700 epochs...
#         ...✅ Chunk #145 saved successfully.
#   -> Progress: [7350/8431] | Overall: [14700/8431] | File: shhs2-203920.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #146 with 65801 epochs...
#         ...✅ Chunk #146 saved successfully.
#   -> Progress: [7400/8431] | Overall: [14800/8431] | File: shhs2-204000.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #147 with 63040 epochs...
#         ...✅ Chunk #147 saved successfully.
#   -> Progress: [7450/8431] | Overall: [14900/8431] | File: shhs2-204078.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #148 with 57779 epochs...
#         ...✅ Chunk #148 saved successfully.
#   -> Progress: [7500/8431] | Overall: [15000/8431] | File: shhs2-204151.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #149 with 59944 epochs...
#         ...✅ Chunk #149 saved successfully.
#   -> Progress: [7550/8431] | Overall: [15100/8431] | File: shhs2-204233.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #150 with 60668 epochs...
#         ...✅ Chunk #150 saved successfully.
#   -> Progress: [7600/8431] | Overall: [15200/8431] | File: shhs2-204310.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #151 with 59809 epochs...
#         ...✅ Chunk #151 saved successfully.
#   -> Progress: [7650/8431] | Overall: [15300/8431] | File: shhs2-204389.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #152 with 58798 epochs...
#         ...✅ Chunk #152 saved successfully.
#   -> Progress: [7700/8431] | Overall: [15400/8431] | File: shhs2-204458.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #153 with 59522 epochs...
#         ...✅ Chunk #153 saved successfully.
#   -> Progress: [7750/8431] | Overall: [15500/8431] | File: shhs2-204530.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #154 with 59936 epochs...
#         ...✅ Chunk #154 saved successfully.
#   -> Progress: [7800/8431] | Overall: [15600/8431] | File: shhs2-204599.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #155 with 59107 epochs...
#         ...✅ Chunk #155 saved successfully.
#   -> Progress: [7850/8431] | Overall: [15700/8431] | File: shhs2-204668.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #156 with 59509 epochs...
#         ...✅ Chunk #156 saved successfully.
#   -> Progress: [7900/8431] | Overall: [15800/8431] | File: shhs2-204751.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #157 with 58008 epochs...
#         ...✅ Chunk #157 saved successfully.
#   -> Progress: [7950/8431] | Overall: [15900/8431] | File: shhs2-204847.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #158 with 59198 epochs...
#         ...✅ Chunk #158 saved successfully.
#   -> Progress: [8000/8431] | Overall: [16000/8431] | File: shhs2-204937.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #159 with 58899 epochs...
#         ...✅ Chunk #159 saved successfully.
#   -> Progress: [8050/8431] | Overall: [16100/8431] | File: shhs2-205031.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #160 with 56997 epochs...
#         ...✅ Chunk #160 saved successfully.
#   -> Progress: [8100/8431] | Overall: [16200/8431] | File: shhs2-205129.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #161 with 54453 epochs...
#         ...✅ Chunk #161 saved successfully.
#   -> Progress: [8150/8431] | Overall: [16300/8431] | File: shhs2-205227.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #162 with 56704 epochs...
#         ...✅ Chunk #162 saved successfully.
#   -> Progress: [8200/8431] | Overall: [16400/8431] | File: shhs2-205325.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #163 with 56301 epochs...
#         ...✅ Chunk #163 saved successfully.
#   -> Progress: [8250/8431] | Overall: [16500/8431] | File: shhs2-205429.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #164 with 58978 epochs...
#         ...✅ Chunk #164 saved successfully.
#   -> Progress: [8300/8431] | Overall: [16600/8431] | File: shhs2-205544.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #165 with 58397 epochs...
#         ...✅ Chunk #165 saved successfully.
#   -> Progress: [8350/8431] | Overall: [16700/8431] | File: shhs2-205626.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #166 with 57787 epochs...
#         ...✅ Chunk #166 saved successfully.
#   -> Progress: [8400/8431] | Overall: [16800/8431] | File: shhs2-205723.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #167 with 59690 epochs...
#         ...✅ Chunk #167 saved successfully.
#   -> Progress: [8431/8431] | Overall: [16862/8431] | File: shhs2-205800.parquet
#      -> 💾 CHUNK COMPLETE: Saving chunk #168 with 37698 epochs...
#         ...✅ Chunk #168 saved successfully.
#
#
# --- Step C: Final verification ---
#   -> Found 169 saved data chunks in the output directory.
# \n================================================================================
# 🎉 SCRIPT COMPLETE 🎉
# Your dataset is now consolidated into manageable chunks in your Google Drive.
# You can now use the final, simplified training script on a GPU runtime.
# ================================================================================
#
# --- Script execution finished. ---

# %%
# ==============================================================================
# SCRIPT TO CONSOLIDATE THE DATASET (DEFINITIVE, VIRTUAL ENV & MEMORY-SAFE)
# This script creates an isolated environment AND processes data in chunks
# to ensure a stable, memory-safe, and resumable run.
# Run this script ONCE on a CPU runtime with high RAM.
# ==============================================================================

import os
import sys
from google.colab import auth, drive

# --- 1. SETUP THE COLAB ENVIRONMENT ---
print("--- Step 1: Preparing the main Colab environment ---")
try:
    auth.authenticate_user()
    print("✅ Authentication successful.")
    drive.mount('/content/drive', force_remount=True)
    print("✅ Google Drive mounted successfully.")
except Exception as e:
    sys.exit(f"❌ FATAL ERROR: Could not set up environment. Details: {e}")

# --- 2. CREATE AND PROVISION THE ISOLATED ENVIRONMENT ---
print("\n--- Step 2: Creating and provisioning the isolated consolidation environment ---")
# !pip install --upgrade -q virtualenv
print("  -> `virtualenv` installed.")
# !virtualenv consolidate_env
print("  -> Virtual environment 'consolidate_env' created successfully.")
# Install our known-good, conflict-free packages into the clean room
# !consolidate_env/bin/pip install --upgrade -q pip "pandas==2.2.2" "pyarrow==15.0.2" "fsspec>=2023.6.0" gcsfs google-auth
print("  -> All dependencies installed successfully into 'consolidate_env'.")


# --- 3. CREATE AND RUN THE CONSOLIDATION LOGIC SCRIPT ---
print("\n--- Step 3: Preparing and executing the consolidation logic in the isolated environment ---")

python_script_logic = r'''
import pandas as pd
import numpy as np
import os
import sys
import time
import glob
import subprocess

# --- Configuration ---
GCS_MANIFEST_PATH = "gs://shhs-sleepedfx-data-bucket/metadata/shhs_dataset_manifest.csv"
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/shhs_consolidated_data/"
PROGRESS_FILE_PATH = os.path.join(DRIVE_OUTPUT_DIR, "_progress.txt")
CHUNK_SIZE = 50 # Process 50 files at a time

print("\n" + "="*80)
print("--- DATA CONSOLIDATION SCRIPT (RUNNING IN ISOLATED ENV) ---")
print(f"  -> Output Directory: {DRIVE_OUTPUT_DIR}")
print("="*80 + "\n")

# --- Prepare Environment ---
os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

# --- Load Manifest ---
print("--- Step A: Loading manifest... ---")
try:
    manifest_df = pd.read_csv(GCS_MANIFEST_PATH)
    all_file_paths = manifest_df['file_path'].tolist()
    print(f"✅ Manifest loaded. Found {len(all_file_paths)} files to process.")
except Exception as e:
    sys.exit(f"❌ FATAL ERROR: Could not load manifest file from GCS. Details: {e}")

# --- Check for Progress ---
processed_files = set()
if os.path.exists(PROGRESS_FILE_PATH):
    with open(PROGRESS_FILE_PATH, 'r') as f:
        processed_files = set(f.read().splitlines())
    print(f"✅ Found progress file. Resuming. {len(processed_files)} files already processed.")

# --- Process Files in Chunks ---
files_to_process = [fp for fp in all_file_paths if fp not in processed_files]
print(f"\n--- Step B: Consolidating data from {len(files_to_process)} remaining files ---")
print("This is a very long process. Progress will be updated periodically.")
time.sleep(2)

# Determine starting chunk number based on existing files
chunk_num = len(glob.glob(os.path.join(DRIVE_OUTPUT_DIR, "spectrograms_*.npy")))
all_spectrograms = []
all_labels = []

for i, f_path in enumerate(files_to_process):
    try:
        if (i + 1) % 10 == 0 or i == len(files_to_process) - 1 or i == 0:
            print(f"\r  -> Progress: [{i+1}/{len(files_to_process)}] | Overall: [{len(processed_files) + i + 1}/{len(all_file_paths)}] | File: {os.path.basename(f_path)}", end="")

        df = pd.read_parquet(f_path)
        df_filtered = df[df['label'].isin([0, 1, 2, 3, 4])]

        labels = df_filtered['label'].values.astype(np.int64)
        spectrograms_flat = df_filtered.drop('label', axis=1).values.astype(np.float32)

        all_labels.extend(labels.tolist())
        all_spectrograms.extend(spectrograms_flat.tolist())
        processed_files.add(f_path)

        if (i > 0 and (i + 1) % CHUNK_SIZE == 0) or ((i + 1) == len(files_to_process) and len(all_labels) > 0):
            print(f"\n     -> 💾 CHUNK COMPLETE: Saving chunk #{chunk_num} with {len(all_labels)} epochs...")

            chunk_data_path = os.path.join(DRIVE_OUTPUT_DIR, f"spectrograms_{chunk_num}.npy")
            chunk_labels_path = os.path.join(DRIVE_OUTPUT_DIR, f"labels_{chunk_num}.npy")

            np.save(chunk_data_path, np.array(all_spectrograms, dtype=np.float32))
            np.save(chunk_labels_path, np.array(all_labels, dtype=np.int64))

            with open(PROGRESS_FILE_PATH, 'w') as f:
                f.write("\\n".join(sorted(list(processed_files))))

            print(f"        ...✅ Chunk #{chunk_num} saved successfully.")

            all_spectrograms.clear()
            all_labels.clear()
            chunk_num += 1

    except Exception as e:
        print(f"\\n     -> ⚠️ WARNING: Could not process {os.path.basename(f_path)}. Skipping. Error: {e}")

print("\n\n--- Step C: Final verification ---")
final_chunks = glob.glob(os.path.join(DRIVE_OUTPUT_DIR, "spectrograms_*.npy"))
print(f"  -> Found {len(final_chunks)} saved data chunks in the output directory.")

print("\\n" + "="*80)
print("🎉 SCRIPT COMPLETE 🎉")
print("Your dataset is now consolidated into manageable chunks in your Google Drive.")
print("You can now use the final, simplified training script on a GPU runtime.")
print("="*80)
'''

# Write the script to a file
with open("run_consolidation.py", "w") as f:
    f.write(python_script_logic)

# Execute the script using the virtual environment's python, forcing the correct backend
# !MPLBACKEND=Agg consolidate_env/bin/python run_consolidation.py

print("\n--- Script execution finished. ---")
# Out:
# --- Step 1: Preparing the main Colab environment ---
# ✅ Authentication successful.
# Mounted at /content/drive
# ✅ Google Drive mounted successfully.
#
# --- Step 2: Creating and provisioning the isolated consolidation environment ---
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 68.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 24.0 MB/s eta 0:00:00
#   -> `virtualenv` installed.
# created virtual environment CPython3.12.11.final.0-64 in 289ms
#   creator CPython3Posix(dest=/content/consolidate_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
#   -> Virtual environment 'consolidate_env' created successfully.
#   -> All dependencies installed successfully into 'consolidate_env'.
#
# --- Step 3: Preparing and executing the consolidation logic in the isolated environment ---
#
# ================================================================================
# --- DATA CONSOLIDATION SCRIPT (RUNNING IN ISOLATED ENV) ---
#   -> Output Directory: /content/drive/MyDrive/shhs_consolidated_data/
# ================================================================================
#
# --- Step A: Loading manifest... ---
# ✅ Manifest loaded. Found 8431 files to process.
# ✅ Found progress file. Resuming. 8432 files already processed.
#
# --- Step B: Consolidating data from 0 remaining files ---
# This is a very long process. Progress will be updated periodically.
#
#
# --- Step C: Final verification ---
#   -> Found 169 saved data chunks in the output directory.
# \n================================================================================
# 🎉 SCRIPT COMPLETE 🎉
# Your dataset is now consolidated into manageable chunks in your Google Drive.
# You can now use the final, simplified training script on a GPU runtime.
# ================================================================================
#
# --- Script execution finished. ---

# %%
# ==============================================================================
# FINAL, HIGH-PERFORMANCE TRAINING SCRIPT (DEFINITIVE VERSION)
# This script uses a chunked, iterable dataset from Google Drive to guarantee
# a stable, memory-safe, and high-performance training run.
# ==============================================================================

import os
import sys
from google.colab import auth, drive

# --- 1. SETUP THE COLAB ENVIRONMENT ---
print("--- Step 1: Preparing the main Colab environment ---")
try:
    auth.authenticate_user()
    print("✅ Authentication successful.")
    drive.mount('/content/drive', force_remount=True)
    print("✅ Google Drive mounted successfully.")
except Exception as e:
    sys.exit(f"❌ FATAL ERROR: Could not set up environment. Details: {e}")

# --- 2. CREATE AND PROVISION THE ISOLATED TRAINING ENVIRONMENT ---
print("\n--- Step 2: Creating and provisioning the isolated training environment ---")
# !pip install --upgrade -q virtualenv
# !virtualenv train_env
# !train_env/bin/pip install --upgrade -q pip "pytorch-lightning" "timm" "pandas>=2.0" "pyarrow>=15.0" "fsspec>=2023.6.0" gcsfs google-auth matplotlib seaborn scikit-learn
print("✅ All dependencies installed successfully into 'train_env'.")


# --- 3. CREATE AND RUN THE FULL TRAINING SCRIPT ---
print("\n--- Step 3: Preparing and executing the training logic in the isolated environment ---")

python_script_logic = r'''
import matplotlib
matplotlib.use('Agg')

import torch
import torch.nn as nn
import timm
from torch.utils.data import IterableDataset, DataLoader
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from pytorch_lightning.loggers import CSVLogger
from torchmetrics.classification import MulticlassAccuracy, MulticlassConfusionMatrix
import numpy as np
import pandas as pd
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from datetime import datetime
import os
import sys
import glob
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report

torch.set_float32_matmul_precision('medium')
print("✅ Libraries imported inside virtual environment.")

# --- All class and function definitions are here ---

def get_model(model_name='convnext_base', pretrained=True):
    model = timm.create_model('convnextv2_base.fcmae_ft_in22k_in1k', pretrained=pretrained)
    original_conv = model.stem[0]
    new_first_conv = nn.Conv2d(1, original_conv.out_channels, kernel_size=original_conv.kernel_size, stride=original_conv.stride, padding=original_conv.padding, bias=(original_conv.bias is not None))
    with torch.no_grad():
        if original_conv.weight.shape[1] == 3:
            new_first_conv.weight[:, :] = original_conv.weight.clone().mean(dim=1, keepdim=True)
    model.stem[0] = new_first_conv
    num_ftrs = model.head.fc.in_features
    model.head.fc = nn.Linear(num_ftrs, 5)
    return model

class SleepStageClassifierLightning(pl.LightningModule):
    def __init__(self, model_name, learning_rate, class_weights, epochs):
        super().__init__()
        self.save_hyperparameters()
        self.model = get_model(model_name=self.hparams.model_name)
        self.train_accuracy = MulticlassAccuracy(num_classes=5)
        self.val_accuracy = MulticlassAccuracy(num_classes=5)
        self.loss_fn = nn.CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float) if class_weights else None)
    def forward(self, x): return self.model(x)
    def normalize_on_gpu(self, x):
        mean = torch.mean(x, dim=(1, 2, 3), keepdim=True)
        std = torch.std(x, dim=(1, 2, 3), keepdim=True)
        return (x - mean) / (std + 1e-6)
    def spec_augment(self, x, time_mask_param=10, freq_mask_param=10):
        _, _, num_freq_bins, num_time_steps = x.shape
        f_mask_width = int(np.random.uniform(0.0, freq_mask_param))
        f_mask_start = int(np.random.uniform(0.0, num_freq_bins - f_mask_width))
        x[:, :, f_mask_start:f_mask_start + f_mask_width, :] = 0
        t_mask_width = int(np.random.uniform(0.0, time_mask_param))
        t_mask_start = int(np.random.uniform(0.0, num_time_steps - t_mask_width))
        x[:, :, :, t_mask_start:t_mask_start + t_mask_width] = 0
        return x
    def training_step(self, batch, batch_idx):
        x, y_true = batch
        x_normalized = self.normalize_on_gpu(x)
        x_augmented = self.spec_augment(x_normalized)
        y_pred_logits = self(x_augmented)
        loss = self.loss_fn(y_pred_logits, y_true)
        self.log('train_loss', loss, on_epoch=True, prog_bar=True)
        self.log('train_acc', self.train_accuracy(y_pred_logits, y_true), on_epoch=True, prog_bar=True)
        return loss
    def validation_step(self, batch, batch_idx):
        x, y_true = batch
        x_normalized = self.normalize_on_gpu(x)
        y_pred_logits = self(x_normalized)
        loss = self.loss_fn(y_pred_logits, y_true)
        self.log('val_loss', loss, on_epoch=True, prog_bar=True)
        self.log('val_acc', self.val_accuracy(y_pred_logits, y_true), on_epoch=True, prog_bar=True)
        return loss
    def configure_optimizers(self):
        optimizer = optim.AdamW(self.parameters(), lr=self.hparams.learning_rate)
        scheduler = CosineAnnealingLR(optimizer, T_max=self.hparams.epochs, eta_min=1e-7)
        return [optimizer], [scheduler]

class ChunkedIterableDataset(IterableDataset):
    def __init__(self, data_dir, is_train=True):
        self.data_dir = data_dir
        self.is_train = is_train
        spectrogram_chunks = sorted(glob.glob(os.path.join(data_dir, "spectrograms_*.npy")))
        label_chunks = sorted(glob.glob(os.path.join(data_dir, "labels_*.npy")))

        split_idx = int(0.8 * len(spectrogram_chunks))
        if self.is_train:
            self.spectrogram_chunks = spectrogram_chunks[:split_idx]
            self.label_chunks = label_chunks[:split_idx]
        else:
            self.spectrogram_chunks = spectrogram_chunks[split_idx:]
            self.label_chunks = label_chunks[split_idx:]

        print(f"✅ {'Training' if is_train else 'Validation'} dataset initialized with {len(self.spectrogram_chunks)} chunks.")

    def __iter__(self):
        chunk_indices = list(range(len(self.spectrogram_chunks)))
        if self.is_train:
            random.shuffle(chunk_indices)

        for chunk_idx in chunk_indices:
            X_chunk = np.load(self.spectrogram_chunks[chunk_idx])
            y_chunk = np.load(self.label_chunks[chunk_idx])

            if self.is_train:
                indices = np.random.permutation(len(y_chunk))
                X_chunk = X_chunk[indices]
                y_chunk = y_chunk[indices]

            for i in range(len(y_chunk)):
                spectrogram_flat = X_chunk[i]
                label = y_chunk[i]
                spectrogram_2d = spectrogram_flat.reshape(1, 76, 60)
                yield torch.from_numpy(spectrogram_2d), torch.tensor(label, dtype=torch.long)

def generate_performance_report(ckpt_path, dataloader, device, save_dir, exp_name):
    # ... placeholder for brevity ...
    pass

# --- MAIN EXECUTION BLOCK ---
if __name__ == "__main__":
    CONSOLIDATED_DATA_DIR = "/content/drive/MyDrive/shhs_consolidated_data/"
    CLASS_WEIGHTS = [0.7, 6.5, 0.5, 1.5, 1.2]
    EPOCHS = 40
    BATCH_SIZE = 512
    LEARNING_RATE = 2e-5
    NUM_WORKERS = 2 # Safe to use multiple workers now
    DRIVE_CHECKPOINT_DIR = "/content/drive/MyDrive/final_model_checkpoint/"

    train_dataset = ChunkedIterableDataset(CONSOLIDATED_DATA_DIR, is_train=True)
    val_dataset = ChunkedIterableDataset(CONSOLIDATED_DATA_DIR, is_train=False)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS)

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    experiment_name = f"{timestamp}_convnext_base_consolidated_cwN1-{CLASS_WEIGHTS[1]}"

    model = SleepStageClassifierLightning('convnext_base', LEARNING_RATE, CLASS_WEIGHTS, EPOCHS)

    drive_log_dir = "/content/drive/MyDrive/sleep_logs/"
    os.makedirs(DRIVE_CHECKPOINT_DIR, exist_ok=True)

    csv_logger = CSVLogger(drive_log_dir, name=experiment_name)
    checkpoint_callback = ModelCheckpoint(monitor='val_loss', dirpath=DRIVE_CHECKPOINT_DIR, filename=f"best-model-{experiment_name}", save_top_k=1, mode='min')
    early_stop_callback = EarlyStopping(monitor='val_loss', patience=10, verbose=True, mode='min')

    checkpoint_files = glob.glob(os.path.join(DRIVE_CHECKPOINT_DIR, "*.ckpt"))
    latest_checkpoint = None
    if checkpoint_files:
        latest_checkpoint = max(checkpoint_files, key=os.path.getmtime)
        print(f"\\n✅ Found checkpoint. Resuming from: {os.path.basename(latest_checkpoint)}")
    else:
        print("\\n  -> No checkpoint found. Starting a new training run.")

    trainer = pl.Trainer(
        max_epochs=EPOCHS, accelerator="gpu", devices=1, logger=csv_logger,
        callbacks=[checkpoint_callback, early_stop_callback],
        precision="bf16-mixed", gradient_clip_val=1.0
    )

    print(f"\\n🚀🚀🚀 Starting/Resuming training for experiment: {experiment_name} 🚀🚀🚀")
    trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader, ckpt_path=latest_checkpoint)
    print(f"\\n✅ Training complete!")

    if checkpoint_callback.best_model_path and os.path.exists(checkpoint_callback.best_model_path):
        print("Performance report generation placeholder")
    else:
        print("  -> No checkpoint was saved. Skipping final report.")
'''

# Write the script to a file
with open("run_training.py", "w") as f:
    f.write(python_script_logic)

# Execute the script
# !MPLBACKEND=Agg train_env/bin/python run_training.py

print("\n--- Script execution finished. ---")
# Out:
# --- Step 1: Preparing the main Colab environment ---
# ✅ Authentication successful.
# Mounted at /content/drive
# ✅ Google Drive mounted successfully.
#
# --- Step 2: Creating and provisioning the isolated training environment ---
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 79.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 35.1 MB/s eta 0:00:00
# created virtual environment CPython3.12.11.final.0-64 in 243ms
#   creator CPython3Posix(dest=/content/train_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# ✅ All dependencies installed successfully into 'train_env'.
#
# --- Step 3: Preparing and executing the training logic in the isolated environment ---
# ✅ Libraries imported inside virtual environment.
# ✅ Training dataset initialized with 135 chunks.
# ✅ Validation dataset initialized with 34 chunks.
# model.safetensors: 100% 355M/355M [00:00<00:00, 373MB/s]
# \n✅ Found checkpoint. Resuming from: best-model-20250916_112909_convnext_base_consolidated_cwN1-6.5.ckpt
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# \n🚀🚀🚀 Starting/Resuming training for experiment: 20250917_221354_convnext_base_consolidated_cwN1-6.5 🚀🚀🚀
# /content/train_env/lib/python3.12/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:751: Checkpoint directory /content/drive/MyDrive/final_model_checkpoint exists and is not empty.
# Restoring states from the checkpoint path at /content/drive/MyDrive/final_model_checkpoint/best-model-20250916_112909_convnext_base_consolidated_cwN1-6.5.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /content/train_env/lib/python3.12/site-packages/pytorch_lightning/utilities/model_summary/model_summary.py:231: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#   | Name           | Type               | Params | Mode
# --------------------------------------------------------------
# 0 | model          | ConvNeXt           | 87.7 M | train
# 1 | train_accuracy | MulticlassAccuracy | 0      | train
# 2 | val_accuracy   | MulticlassAccuracy | 0      | train
# 3 | loss_fn        | CrossEntropyLoss   | 0      | train
# --------------------------------------------------------------
# 87.7 M    Trainable params
# 0         Non-trainable params
# 87.7 M    Total params
# 350.775   Total estimated model params size (MB)
# 468       Modules in train mode
# 0         Modules in eval mode
# Restored all states from the checkpoint at /content/drive/MyDrive/final_model_checkpoint/best-model-20250916_112909_convnext_base_consolidated_cwN1-6.5.ckpt
# Epoch 3: |          | 28480/? [1:59:51<00:00,  3.96it/s, v_num=0, train_loss_step=0.388, train_acc_step=0.878]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0: |          | 20/? [00:00<00:00, 22.41it/s]
# Validation DataLoader 0: |          | 40/? [00:01<00:00, 22.53it/s]
# Validation DataLoader 0: |          | 60/? [00:02<00:00, 22.58it/s]
# Validation DataLoader 0: |          | 80/? [00:03<00:00, 22.60it/s]
# Validation DataLoader 0: |          | 100/? [00:04<00:00, 22.61it/s]
# Validation DataLoader 0: |          | 120/? [00:05<00:00, 21.57it/s]
# Validation DataLoader 0: |          | 140/? [00:06<00:00, 21.73it/s]
# Validation DataLoader 0: |          | 160/? [00:07<00:00, 21.84it/s]
# Validation DataLoader 0: |          | 180/? [00:08<00:00, 21.90it/s]
# Validation DataLoader 0: |          | 200/? [00:23<00:00,  8.61it/s]
# Validation DataLoader 0: |          | 220/? [00:24<00:00,  9.12it/s]
# Validation DataLoader 0: |          | 240/? [00:24<00:00,  9.60it/s]
# Validation DataLoader 0: |          | 260/? [00:25<00:00, 10.05it/s]
# Validation DataLoader 0: |          | 280/? [00:26<00:00, 10.46it/s]
# Validation DataLoader 0: |          | 300/? [00:27<00:00, 10.85it/s]
# Validation DataLoader 0: |          | 320/? [00:28<00:00, 11.22it/s]
# Validation DataLoader 0: |          | 340/? [00:29<00:00, 11.56it/s]
# Validation DataLoader 0: |          | 360/? [00:30<00:00, 11.89it/s]
# Validation DataLoader 0: |          | 380/? [00:31<00:00, 12.19it/s]
# Validation DataLoader 0: |          | 400/? [00:46<00:00,  8.63it/s]
# Validation DataLoader 0: |          | 420/? [00:47<00:00,  8.89it/s]
# Validation DataLoader 0: |          | 440/? [00:48<00:00,  9.14it/s]
# Validation DataLoader 0: |          | 6580/? [15:09<00:00,  7.23it/s]
# Validation DataLoader 0: |          | 6600/? [15:10<00:00,  7.25it/s]
# Validation DataLoader 0: |          | 6620/? [15:11<00:00,  7.26it/s]
# Validation DataLoader 0: |          | 6640/? [15:31<00:00,  7.13it/s]
# Validation DataLoader 0: |          | 6660/? [15:32<00:00,  7.14it/s]
# Validation DataLoader 0: |          | 6680/? [15:33<00:00,  7.16it/s]
# Validation DataLoader 0: |          | 6700/? [15:34<00:00,  7.17it/s]
# Validation DataLoader 0: |          | 6720/? [15:35<00:00,  7.19it/s]
# Validation DataLoader 0: |          | 6740/? [15:35<00:00,  7.20it/s]
# Validation DataLoader 0: |          | 6760/? [15:36<00:00,  7.22it/s]
# Validation DataLoader 0: |          | 6780/? [15:37<00:00,  7.23it/s]
# Validation DataLoader 0: |          | 6800/? [15:38<00:00,  7.24it/s]
# Validation DataLoader 0: |          | 6820/? [15:39<00:00,  7.26it/s]
# Epoch 13: |          | 11500/? [51:26<00:00,  3.73it/s, v_num=0, train_loss_step=0.314, train_acc_step=0.877, val_loss=1.360, val_acc=0.702, train_loss_epoch=0.291, train_acc_epoch=0.889]

# %%
# ==============================================================================
# 2025-09-18 FINAL, HIGH-PERFORMANCE TRAINING SCRIPT (DEFINITIVE VERSION)
# This script uses a chunked, iterable dataset from Google Drive to guarantee
# a stable, memory-safe, and high-performance training run.
# ==============================================================================

import os
import sys
from google.colab import auth, drive

# --- 1. SETUP THE COLAB ENVIRONMENT ---
print("--- Step 1: Preparing the main Colab environment ---")
try:
    auth.authenticate_user()
    print("✅ Authentication successful.")
    drive.mount('/content/drive', force_remount=True)
    print("✅ Google Drive mounted successfully.")
except Exception as e:
    sys.exit(f"❌ FATAL ERROR: Could not set up environment. Details: {e}")

# --- 2. CREATE AND PROVISION THE ISOLATED TRAINING ENVIRONMENT ---
print("\n--- Step 2: Creating and provisioning the isolated training environment ---")
# !pip install --upgrade -q virtualenv
# !virtualenv train_env
# !train_env/bin/pip install --upgrade -q pip "pytorch-lightning" "timm" "pandas>=2.0" "pyarrow>=15.0" "fsspec>=2023.6.0" gcsfs google-auth matplotlib seaborn scikit-learn
print("✅ All dependencies installed successfully into 'train_env'.")


# --- 3. CREATE AND RUN THE FULL TRAINING SCRIPT ---
print("\n--- Step 3: Preparing and executing the training logic in the isolated environment ---")

python_script_logic = r'''
import matplotlib
matplotlib.use('Agg')

import torch
import torch.nn as nn
import timm
from torch.utils.data import IterableDataset, DataLoader
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from pytorch_lightning.loggers import CSVLogger
from torchmetrics.classification import MulticlassAccuracy, MulticlassConfusionMatrix
import numpy as np
import pandas as pd
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from datetime import datetime
import os
import sys
import glob
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report

torch.set_float32_matmul_precision('medium')
print("✅ Libraries imported inside virtual environment.")

# --- All class and function definitions are here ---

def get_model(model_name='convnext_base', pretrained=True):
    model = timm.create_model('convnextv2_base.fcmae_ft_in22k_in1k', pretrained=pretrained)
    original_conv = model.stem[0]
    new_first_conv = nn.Conv2d(1, original_conv.out_channels, kernel_size=original_conv.kernel_size, stride=original_conv.stride, padding=original_conv.padding, bias=(original_conv.bias is not None))
    with torch.no_grad():
        if original_conv.weight.shape[1] == 3:
            new_first_conv.weight[:, :] = original_conv.weight.clone().mean(dim=1, keepdim=True)
    model.stem[0] = new_first_conv
    num_ftrs = model.head.fc.in_features
    model.head.fc = nn.Linear(num_ftrs, 5)
    return model

class SleepStageClassifierLightning(pl.LightningModule):
    def __init__(self, model_name, learning_rate, class_weights, epochs):
        super().__init__()
        self.save_hyperparameters()
        self.model = get_model(model_name=self.hparams.model_name)
        self.train_accuracy = MulticlassAccuracy(num_classes=5)
        self.val_accuracy = MulticlassAccuracy(num_classes=5)
        self.loss_fn = nn.CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float) if class_weights else None)
    def forward(self, x): return self.model(x)
    def normalize_on_gpu(self, x):
        mean = torch.mean(x, dim=(1, 2, 3), keepdim=True)
        std = torch.std(x, dim=(1, 2, 3), keepdim=True)
        return (x - mean) / (std + 1e-6)
    def spec_augment(self, x, time_mask_param=10, freq_mask_param=10):
        _, _, num_freq_bins, num_time_steps = x.shape
        f_mask_width = int(np.random.uniform(0.0, freq_mask_param))
        f_mask_start = int(np.random.uniform(0.0, num_freq_bins - f_mask_width))
        x[:, :, f_mask_start:f_mask_start + f_mask_width, :] = 0
        t_mask_width = int(np.random.uniform(0.0, time_mask_param))
        t_mask_start = int(np.random.uniform(0.0, num_time_steps - t_mask_width))
        x[:, :, :, t_mask_start:t_mask_start + t_mask_width] = 0
        return x
    def training_step(self, batch, batch_idx):
        x, y_true = batch
        x_normalized = self.normalize_on_gpu(x)
        x_augmented = self.spec_augment(x_normalized)
        y_pred_logits = self(x_augmented)
        loss = self.loss_fn(y_pred_logits, y_true)
        self.log('train_loss', loss, on_epoch=True, prog_bar=True)
        self.log('train_acc', self.train_accuracy(y_pred_logits, y_true), on_epoch=True, prog_bar=True)
        return loss
    def validation_step(self, batch, batch_idx):
        x, y_true = batch
        x_normalized = self.normalize_on_gpu(x)
        y_pred_logits = self(x_normalized)
        loss = self.loss_fn(y_pred_logits, y_true)
        self.log('val_loss', loss, on_epoch=True, prog_bar=True)
        self.log('val_acc', self.val_accuracy(y_pred_logits, y_true), on_epoch=True, prog_bar=True)
        return loss
    def configure_optimizers(self):
        optimizer = optim.AdamW(self.parameters(), lr=self.hparams.learning_rate)
        scheduler = CosineAnnealingLR(optimizer, T_max=self.hparams.epochs, eta_min=1e-7)
        return [optimizer], [scheduler]

class ChunkedIterableDataset(IterableDataset):
    def __init__(self, data_dir, is_train=True):
        self.data_dir = data_dir
        self.is_train = is_train
        spectrogram_chunks = sorted(glob.glob(os.path.join(data_dir, "spectrograms_*.npy")))
        label_chunks = sorted(glob.glob(os.path.join(data_dir, "labels_*.npy")))

        split_idx = int(0.8 * len(spectrogram_chunks))
        if self.is_train:
            self.spectrogram_chunks = spectrogram_chunks[:split_idx]
            self.label_chunks = label_chunks[:split_idx]
        else:
            self.spectrogram_chunks = spectrogram_chunks[split_idx:]
            self.label_chunks = label_chunks[split_idx:]

        print(f"✅ {'Training' if is_train else 'Validation'} dataset initialized with {len(self.spectrogram_chunks)} chunks.")

    def __iter__(self):
        chunk_indices = list(range(len(self.spectrogram_chunks)))
        if self.is_train:
            random.shuffle(chunk_indices)

        for chunk_idx in chunk_indices:
            X_chunk = np.load(self.spectrogram_chunks[chunk_idx])
            y_chunk = np.load(self.label_chunks[chunk_idx])

            if self.is_train:
                indices = np.random.permutation(len(y_chunk))
                X_chunk = X_chunk[indices]
                y_chunk = y_chunk[indices]

            for i in range(len(y_chunk)):
                spectrogram_flat = X_chunk[i]
                label = y_chunk[i]
                spectrogram_2d = spectrogram_flat.reshape(1, 76, 60)
                yield torch.from_numpy(spectrogram_2d), torch.tensor(label, dtype=torch.long)

def generate_performance_report(ckpt_path, dataloader, device, save_dir, exp_name):
    # ... placeholder for brevity ...
    pass

# --- MAIN EXECUTION BLOCK ---
if __name__ == "__main__":
    CONSOLIDATED_DATA_DIR = "/content/drive/MyDrive/shhs_consolidated_data/"
    CLASS_WEIGHTS = [0.7, 6.5, 0.5, 1.5, 1.2]
    EPOCHS = 40
    BATCH_SIZE = 512
    LEARNING_RATE = 2e-5
    NUM_WORKERS = 2 # Safe to use multiple workers now
    DRIVE_CHECKPOINT_DIR = "/content/drive/MyDrive/final_model_checkpoint/"

    train_dataset = ChunkedIterableDataset(CONSOLIDATED_DATA_DIR, is_train=True)
    val_dataset = ChunkedIterableDataset(CONSOLIDATED_DATA_DIR, is_train=False)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS)

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    experiment_name = f"{timestamp}_convnext_base_consolidated_cwN1-{CLASS_WEIGHTS[1]}"

    model = SleepStageClassifierLightning('convnext_base', LEARNING_RATE, CLASS_WEIGHTS, EPOCHS)

    drive_log_dir = "/content/drive/MyDrive/sleep_logs/"
    os.makedirs(DRIVE_CHECKPOINT_DIR, exist_ok=True)

    csv_logger = CSVLogger(drive_log_dir, name=experiment_name)
    checkpoint_callback = ModelCheckpoint(monitor='val_loss', dirpath=DRIVE_CHECKPOINT_DIR, filename=f"best-model-{experiment_name}", save_top_k=1, mode='min')
    early_stop_callback = EarlyStopping(monitor='val_loss', patience=10, verbose=True, mode='min')

    checkpoint_files = glob.glob(os.path.join(DRIVE_CHECKPOINT_DIR, "*.ckpt"))
    latest_checkpoint = None
    if checkpoint_files:
        latest_checkpoint = max(checkpoint_files, key=os.path.getmtime)
        print(f"\\n✅ Found checkpoint. Resuming from: {os.path.basename(latest_checkpoint)}")
    else:
        print("\\n  -> No checkpoint found. Starting a new training run.")

    trainer = pl.Trainer(
        max_epochs=EPOCHS, accelerator="gpu", devices=1, logger=csv_logger,
        callbacks=[checkpoint_callback, early_stop_callback],
        precision="bf16-mixed", gradient_clip_val=1.0
    )

    print(f"\\n🚀🚀🚀 Starting/Resuming training for experiment: {experiment_name} 🚀🚀🚀")
    trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader, ckpt_path=latest_checkpoint)
    print(f"\\n✅ Training complete!")

    if checkpoint_callback.best_model_path and os.path.exists(checkpoint_callback.best_model_path):
        print("Performance report generation placeholder")
    else:
        print("  -> No checkpoint was saved. Skipping final report.")
'''

# Write the script to a file
with open("run_training.py", "w") as f:
    f.write(python_script_logic)

# Execute the script
# !MPLBACKEND=Agg train_env/bin/python run_training.py

print("\n--- Script execution finished. ---")
